# %%
import numpy as np
import pandas as pd
import os
import torch
import arnet
from arnet import ARNet
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DIR = os.path.dirname(os.path.abspath(''))
data_path = os.path.join(DIR, 'ar_data')
name = 'ar_3_ma_0_noise_0.100_len_10000'
df = pd.read_csv(os.path.join(data_path, name + '.csv'), header=None, index_col=False)

# %%
m = arnet.ARNet(
    ar_order=10,
    sparsity=0.5,
    n_epoch=10,
    loss_func="MSE",
    valid_p=0.1,
    use_gpu=False,
)
m = m.fit(df, plot=True)
# Out:
# INFO: ARNet - tabularize: estimated noise of series: 0.12804202767787692
# INFO: ARNet - create_regularizer: reg lam (max): 0.009999999980000004
# INFO: ARNet - find_lr: Optimal learning rate: 0.08004483580589294
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mse</th>
#       <th>mae</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.010328</td>
#       <td>0.010381</td>
#       <td>0.010381</td>
#       <td>0.081726</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.011120</td>
#       <td>0.010777</td>
#       <td>0.010777</td>
#       <td>0.083936</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.012526</td>
#       <td>0.010890</td>
#       <td>0.010890</td>
#       <td>0.082217</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012527</td>
#       <td>0.010245</td>
#       <td>0.010245</td>
#       <td>0.080061</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.013956</td>
#       <td>0.011133</td>
#       <td>0.011133</td>
#       <td>0.084477</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.013491</td>
#       <td>0.011967</td>
#       <td>0.011967</td>
#       <td>0.087757</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.013403</td>
#       <td>0.010084</td>
#       <td>0.010084</td>
#       <td>0.080686</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012598</td>
#       <td>0.009755</td>
#       <td>0.009755</td>
#       <td>0.078797</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.012318</td>
#       <td>0.009999</td>
#       <td>0.009999</td>
#       <td>0.079772</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.012411</td>
#       <td>0.009749</td>
#       <td>0.009749</td>
#       <td>0.078899</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
m.plot_weights()

# %%
m.plot_fitted_obs()

# %%
m.plot_errors()
